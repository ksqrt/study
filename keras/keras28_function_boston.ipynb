# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import sklearn as sk
dataset = load_boston()
# Out:
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#   warnings.warn(msg, category=FutureWarning)

# %%
x = dataset.data
y = dataset.target
x= pd.DataFrame(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  0       0.00632
# 1       0.00000
# 2       0.46000
# 3       0.00000
# 4       0.38500
# 5       3.56100
# 6       2.90000
# 7       1.12960
# 8       1.00000
# 9     187.00000
# 10     12.60000
# 11      0.32000
# 12      1.73000
# dtype: float64
# x 최댓값 :  0      88.9762
# 1     100.0000
# 2      27.7400
# 3       1.0000
# 4       0.8710
# 5       8.7800
# 6     100.0000
# 7      12.1265
# 8      24.0000
# 9     711.0000
# 10     22.0000
# 11    396.9000
# 12     37.9700
# dtype: float64
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# 스케일링 하기
scaler = StandardScaler()
# 가중치 생성후
scaler.fit(x)
# 변환
x = scaler.transform(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  -3.9071933049810337
# x 최댓값 :  9.933930601860268

# %%
# 13개의 칼럼 을 가지고있는 데이터를 조회합니다
print(x.shape) #(506,13)
# print(x)
print(y.shape) #(506,)
# print(y)
# Out:
# (506, 13)
# (506,)

# %%
# 사이킥 런의 칼럼 조회기능
print(dataset.feature_names)
print(len(dataset.feature_names))
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# 13

# %%
# 사이킥런의 데이터 요약
# print(dataset.DESCR)

# %%
# 3. 모델구성
# 실습 train 0.7 이상
# 평가지표 R2 : 0.8 이상으로 뽑아내보기 / RMSE 사용

x_train, x_test,y_train,y_test = train_test_split(x,y,
    train_size=0.7,
    shuffle = True,
    random_state= 123
)

scaler = MinMaxScaler()
# 가중치 생성후
scaler.fit(x_train)
# x_train 의 가중치 변환
x_train = scaler.transform(x_train)
# x_test 는 변환만 !
x_test = scaler.transform(x_test)

print(len(x_train))
print(len(x_test))
# Out:
# 354
# 152

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Input


# 2. 모델구성 순차형
model = Sequential([
    Dense(50,input_dim=13,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(1)
])


# 3. 모델구성 함수형
input1 = Input(shape=(13,))
dense1 = Dense(50,activation="relu")(input1)
dense2 = Dense(50,activation="relu")(dense1)
dense3 = Dense(50,activation="relu")(dense2)
dense4 = Dense(50,activation="relu")(dense3)
dense5 = Dense(50,activation="relu")(dense4)
output1 = Dense(1,activation="relu")(dense5)

model=Model(inputs=input1,outputs=output1)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 13)]              0
#
#  dense_60 (Dense)            (None, 50)                700
#
#  dense_61 (Dense)            (None, 50)                2550
#
#  dense_62 (Dense)            (None, 50)                2550
#
#  dense_63 (Dense)            (None, 50)                2550
#
#  dense_64 (Dense)            (None, 50)                2550
#
#  dense_65 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 10,951
# Trainable params: 10,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.compile(loss="mae",optimizer="adam")

model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.25)
# loss = model.evaluate(x_test,y_test)
# print("loss : ",loss)
# y_predict =model.predict(x_test)
# print("=================")
# print(y_test)
# print(y_predict)
# print("=================")
# r2 = r2_score(y_test,y_predict)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s
100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.3910 - val_loss: 2.9814
# Epoch 44/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.4401 - val_loss: 2.9030
# Epoch 45/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2879 - val_loss: 2.9275
# Epoch 46/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3539 - val_loss: 3.1504
# Epoch 47/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3081 - val_loss: 3.0682
# Epoch 48/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.4198 - val_loss: 2.8468
# Epoch 49/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3061 - val_loss: 2.8068
# Epoch 50/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2775 - val_loss: 2.8535
# Epoch 51/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2395 - val_loss: 2.8380
# Epoch 52/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3714 - val_loss: 3.1072
# Epoch 53/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3281 - val_loss: 3.1738
# Epoch 54/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2932 - val_loss: 2.9982
# Epoch 55/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3215 - val_loss: 2.8070
# Epoch 56/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1681 - val_loss: 2.9754
# Epoch 57/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1883 - val_loss: 3.1384
# Epoch 58/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.3519 - val_loss: 2.8072
# Epoch 59/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1142 - val_loss: 2.8409
# Epoch 60/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1248 - val_loss: 2.8087
# Epoch 61/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1087 - val_loss: 2.8590
# Epoch 62/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0937 - val_loss: 2.7813
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1009 - val_loss: 2.9930
# Epoch 64/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1575 - val_loss: 2.9647
# Epoch 65/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2063 - val_loss: 2.7852
# Epoch 66/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0683 - val_loss: 2.7887
# Epoch 67/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0711 - val_loss: 2.7466
# Epoch 68/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2666 - val_loss: 2.9490
# Epoch 69/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0806 - val_loss: 3.0021
# Epoch 70/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1601 - val_loss: 2.7981
# Epoch 71/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1660 - val_loss: 2.7399
# Epoch 72/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.1301 - val_loss: 2.6522
# Epoch 73/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1041 - val_loss: 2.8683
# Epoch 74/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1017 - val_loss: 2.9620
# Epoch 75/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0419 - val_loss: 2.8715
# Epoch 76/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1064 - val_loss: 2.6931
# Epoch 77/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0689 - val_loss: 2.7312
# Epoch 78/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.9835 - val_loss: 2.6697
# Epoch 79/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1158 - val_loss: 3.0053
# Epoch 80/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1015 - val_loss: 3.0367
# Epoch 81/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0960 - val_loss: 2.6837
# Epoch 82/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1180 - val_loss: 2.7020
# Epoch 83/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0662 - val_loss: 2.8338
# Epoch 84/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9902 - val_loss: 2.9480
# Epoch 85/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9881 - val_loss: 2.6756
# Epoch 86/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9683 - val_loss: 2.6564
# Epoch 87/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.9330 - val_loss: 2.6686
# Epoch 88/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0157 - val_loss: 3.0101
# Epoch 89/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9744 - val_loss: 2.6565
# Epoch 90/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9358 - val_loss: 2.6538
# Epoch 91/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1017 - val_loss: 2.7708
# Epoch 92/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.9282 - val_loss: 2.7234
# Epoch 93/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.8790 - val_loss: 2.6715
# Epoch 94/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.8455 - val_loss: 2.7574
# Epoch 95/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.8634 - val_loss: 2.8384
# Epoch 96/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.9191 - val_loss: 2.6028
# Epoch 97/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9712 - val_loss: 2.6687
# Epoch 98/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.0280 - val_loss: 2.6171
# Epoch 99/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9819 - val_loss: 3.1944
# Epoch 100/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9960 - val_loss: 2.5887
