# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import sklearn as sk
dataset = load_boston()
# Out:
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#   warnings.warn(msg, category=FutureWarning)

# %%
x = dataset.data
y = dataset.target
x= pd.DataFrame(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  0       0.00632
# 1       0.00000
# 2       0.46000
# 3       0.00000
# 4       0.38500
# 5       3.56100
# 6       2.90000
# 7       1.12960
# 8       1.00000
# 9     187.00000
# 10     12.60000
# 11      0.32000
# 12      1.73000
# dtype: float64
# x 최댓값 :  0      88.9762
# 1     100.0000
# 2      27.7400
# 3       1.0000
# 4       0.8710
# 5       8.7800
# 6     100.0000
# 7      12.1265
# 8      24.0000
# 9     711.0000
# 10     22.0000
# 11    396.9000
# 12     37.9700
# dtype: float64
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# 스케일링 하기
scaler = StandardScaler()
# 가중치 생성후
scaler.fit(x)
# 변환
x = scaler.transform(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  -3.9071933049810337
# x 최댓값 :  9.933930601860268

# %%
# 13개의 칼럼 을 가지고있는 데이터를 조회합니다
print(x.shape) #(506,13)
# print(x)
print(y.shape) #(506,)
# print(y)
# Out:
# (506, 13)
# (506,)

# %%
# 사이킥 런의 칼럼 조회기능
print(dataset.feature_names)
print(len(dataset.feature_names))
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# 13

# %%
# 사이킥런의 데이터 요약
# print(dataset.DESCR)

# %%
# 3. 모델구성
# 실습 train 0.7 이상
# 평가지표 R2 : 0.8 이상으로 뽑아내보기 / RMSE 사용

x_train, x_test,y_train,y_test = train_test_split(x,y,
    train_size=0.7,
    shuffle = True,
    random_state= 123
)

scaler = MinMaxScaler()
# 가중치 생성후
scaler.fit(x_train)
# x_train 의 가중치 변환
x_train = scaler.transform(x_train)
# x_test 는 변환만 !
x_test = scaler.transform(x_test)

print(len(x_train))
print(len(x_test))
# Out:
# 354
# 152

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense,Input


# 2. 모델구성 순차형
model = Sequential([
    Dense(50,input_dim=13,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(50,activation="relu"),
    Dense(1)
])


# 3. 모델구성 함수형
input1 = Input(shape=(13,))
dense1 = Dense(50,activation="relu")(input1)
dense2 = Dense(50,activation="relu")(dense1)
dense3 = Dense(50,activation="relu")(dense2)
dense4 = Dense(50,activation="relu")(dense3)
dense5 = Dense(50,activation="relu")(dense4)
output1 = Dense(1,activation="relu")(dense5)

model=Model(inputs=input1,outputs=output1)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 13)]              0
#
#  dense_6 (Dense)             (None, 50)                700
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 50)                2550
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 50)                2550
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 10,951
# Trainable params: 10,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.compile(loss="mae",optimizer="adam")

model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.25)
# loss = model.evaluate(x_test,y_test)
# print("loss : ",loss)
# y_predict =model.predict(x_test)
# print("=================")
# print(y_test)
# print(y_predict)
# print("=================")
# r2 = r2_score(y_test,y_predict)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s
# Epoch 29/100
# 9/9 [==============================] - 0s 34ms/step - loss: 2.7360 - val_loss: 3.1346
# Epoch 30/100
# 9/9 [==============================] - 0s 32ms/step - loss: 2.4725 - val_loss: 3.0083
# Epoch 31/100
# 9/9 [==============================] - 0s 41ms/step - loss: 2.4411 - val_loss: 2.9597
# Epoch 32/100
# 9/9 [==============================] - 0s 36ms/step - loss: 2.4065 - val_loss: 3.2968
# Epoch 33/100
# 9/9 [==============================] - 0s 21ms/step - loss: 2.5262 - val_loss: 2.9771
# Epoch 34/100
# 9/9 [==============================] - 0s 45ms/step - loss: 2.3830 - val_loss: 2.8971
# Epoch 35/100
# 9/9 [==============================] - 0s 25ms/step - loss: 2.4078 - val_loss: 2.8508
# Epoch 36/100
# 9/9 [==============================] - 1s 67ms/step - loss: 2.3630 - val_loss: 2.9013
# Epoch 37/100
# 9/9 [==============================] - 1s 113ms/step - loss: 2.3218 - val_loss: 3.0975
# Epoch 38/100
# 9/9 [==============================] - 1s 136ms/step - loss: 2.3823 - val_loss: 2.7810
# Epoch 39/100
# 9/9 [==============================] - 0s 40ms/step - loss: 2.5423 - val_loss: 2.8768
# Epoch 40/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.4766 - val_loss: 2.8659
# Epoch 41/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.4141 - val_loss: 3.2932
# Epoch 42/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.4145 - val_loss: 2.9018
# Epoch 43/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2830 - val_loss: 2.7367
# Epoch 44/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3525 - val_loss: 3.0737
# Epoch 45/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2992 - val_loss: 2.9806
# Epoch 46/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.3218 - val_loss: 2.7090
# Epoch 47/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2408 - val_loss: 2.8623
# Epoch 48/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2255 - val_loss: 2.8392
# Epoch 49/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1828 - val_loss: 2.8448
# Epoch 50/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1568 - val_loss: 2.7434
# Epoch 51/100
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3544 - val_loss: 2.6907
# Epoch 52/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2283 - val_loss: 2.7026
# Epoch 53/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1947 - val_loss: 2.8518
# Epoch 54/100
# 9/9 [==============================] - 1s 80ms/step - loss: 2.1372 - val_loss: 3.0574
# Epoch 55/100
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1755 - val_loss: 2.7168
# Epoch 56/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1645 - val_loss: 2.6314
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.0990 - val_loss: 2.7259
# Epoch 58/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0419 - val_loss: 2.7412
# Epoch 59/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0339 - val_loss: 2.7001
# Epoch 60/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0286 - val_loss: 2.7056
# Epoch 61/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1029 - val_loss: 2.6441
# Epoch 62/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1203 - val_loss: 3.0157
# Epoch 63/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1334 - val_loss: 3.2100
# Epoch 64/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2909 - val_loss: 2.8556
# Epoch 65/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.2157 - val_loss: 2.7963
# Epoch 66/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2.0737 - val_loss: 2.8518
# Epoch 67/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.0471 - val_loss: 2.8261
# Epoch 68/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1.9956 - val_loss: 2.7356
# Epoch 69/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.0040 - val_loss: 2.8637
# Epoch 70/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.1959 - val_loss: 3.0227
# Epoch 71/100
# 9/9 [==============================] - 0s 9ms/step - loss: 2.1570 - val_loss: 3.2309
# Epoch 72/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.0856 - val_loss: 2.7568
# Epoch 73/100
# 9/9 [==============================] - 0s 11ms/step - loss: 2.1545 - val_loss: 2.7271
# Epoch 74/100
# 9/9 [==============================] - 0s 14ms/step - loss: 2.0849 - val_loss: 2.7413
# Epoch 75/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.9818 - val_loss: 2.8706
# Epoch 76/100
# 9/9 [==============================] - 0s 19ms/step - loss: 1.9848 - val_loss: 2.7468
# Epoch 77/100
# 9/9 [==============================] - 0s 17ms/step - loss: 1.9103 - val_loss: 2.7961
# Epoch 78/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.9298 - val_loss: 2.7620
# Epoch 79/100
# 9/9 [==============================] - 0s 11ms/step - loss: 1.9592 - val_loss: 2.8555
# Epoch 80/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.0318 - val_loss: 2.8795
# Epoch 81/100
# 9/9 [==============================] - 0s 18ms/step - loss: 1.9426 - val_loss: 2.8347
# Epoch 82/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.9431 - val_loss: 2.7829
# Epoch 83/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.8704 - val_loss: 2.7996
# Epoch 84/100
# 9/9 [==============================] - 0s 23ms/step - loss: 1.9115 - val_loss: 2.9631
# Epoch 85/100
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8890 - val_loss: 2.8057
# Epoch 86/100
# 9/9 [==============================] - 0s 10ms/step - loss: 1.8633 - val_loss: 2.8783
# Epoch 87/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.9073 - val_loss: 2.8923
# Epoch 88/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.8616 - val_loss: 2.7699
# Epoch 89/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.8671 - val_loss: 2.7948
# Epoch 90/100
# 9/9 [==============================] - 0s 19ms/step - loss: 1.8369 - val_loss: 2.8198
# Epoch 91/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.8917 - val_loss: 2.8153
# Epoch 92/100
# 9/9 [==============================] - 0s 11ms/step - loss: 1.9320 - val_loss: 2.9866
# Epoch 93/100
# 9/9 [==============================] - 0s 24ms/step - loss: 1.9688 - val_loss: 2.9562
# Epoch 94/100
# 9/9 [==============================] - 0s 54ms/step - loss: 1.8564 - val_loss: 3.3063
# Epoch 95/100
# 9/9 [==============================] - 0s 53ms/step - loss: 2.1810 - val_loss: 2.7081
# Epoch 96/100
# 9/9 [==============================] - 0s 56ms/step - loss: 2.0865 - val_loss: 2.7346
# Epoch 97/100
# 9/9 [==============================] - 0s 20ms/step - loss: 1.9006 - val_loss: 2.7221
# Epoch 98/100
# 9/9 [==============================] - 0s 50ms/step - loss: 1.8953 - val_loss: 2.8300
# Epoch 99/100
# 9/9 [==============================] - 0s 41ms/step - loss: 1.8052 - val_loss: 2.8867
# Epoch 100/100
# 9/9 [==============================] - 0s 18ms/step - loss: 1.8101 - val_loss: 2.7507
