# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import sklearn as sk
dataset = load_boston()
# Out:
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#   warnings.warn(msg, category=FutureWarning)

# %%
x = dataset.data
y = dataset.target
x= pd.DataFrame(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  0       0.00632
# 1       0.00000
# 2       0.46000
# 3       0.00000
# 4       0.38500
# 5       3.56100
# 6       2.90000
# 7       1.12960
# 8       1.00000
# 9     187.00000
# 10     12.60000
# 11      0.32000
# 12      1.73000
# dtype: float64
# x 최댓값 :  0      88.9762
# 1     100.0000
# 2      27.7400
# 3       1.0000
# 4       0.8710
# 5       8.7800
# 6     100.0000
# 7      12.1265
# 8      24.0000
# 9     711.0000
# 10     22.0000
# 11    396.9000
# 12     37.9700
# dtype: float64
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\bitcamp\anaconda3\envs\tf274gpu\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# 스케일링 하기
scaler = StandardScaler()
# 가중치 생성후
scaler.fit(x)
# 변환
x = scaler.transform(x)
print("x 최솟값 : ",np.min(x))
print("x 최댓값 : ",np.max(x))
# Out:
# x 최솟값 :  -3.9071933049810337
# x 최댓값 :  9.933930601860268

# %%
# 13개의 칼럼 을 가지고있는 데이터를 조회합니다
print(x.shape) #(506,13)
# print(x)
print(y.shape) #(506,)
# print(y)
# Out:
# (506, 13)
# (506,)

# %%
# 사이킥 런의 칼럼 조회기능
print(dataset.feature_names)
print(len(dataset.feature_names))
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# 13

# %%
# 사이킥런의 데이터 요약
# print(dataset.DESCR)

# %%
# 3. 모델구성
# 실습 train 0.7 이상
# 평가지표 R2 : 0.8 이상으로 뽑아내보기 / RMSE 사용

x_train, x_test,y_train,y_test = train_test_split(x,y,
    train_size=0.7,
    shuffle = True,
    random_state= 123
)

scaler = MinMaxScaler()
# 가중치 생성후
scaler.fit(x_train)
# x_train 의 가중치 변환
x_train = scaler.transform(x_train)
# x_test 는 변환만 !
x_test = scaler.transform(x_test)

print(len(x_train))
print(len(x_test))
# Out:
# 354
# 152

# %%
from random import randrange
number1 = randrange(1,10,1)

model = Sequential([
    Dense(10,input_dim = 13,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_8 (Dense)             (None, 10)                110
#
#  dense_9 (Dense)             (None, 10)                110
#
#  dense_10 (Dense)            (None, 10)                110
#
#  dense_11 (Dense)            (None, 10)                110
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 10)                110
#
#  dense_15 (Dense)            (None, 10)                110
#
#  dense_16 (Dense)            (None, 10)                110
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,911
# Trainable params: 1,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.compile(loss="mae",optimizer="adam")

model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.25)
# loss = model.evaluate(x_test,y_test)
# print("loss : ",loss)
# y_predict =model.predict(x_test)
# print("=================")
# print(y_test)
# print(y_predict)
# print("=================")
# r2 = r2_score(y_test,y_predict)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 26ms/step - loss: 22.7702 - val_loss: 22.6130
# Epoch 2/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.7023 - val_loss: 22.5206
# Epoch 3/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.5809 - val_loss: 22.3362
# Epoch 4/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.3177 - val_loss: 21.9033
# Epoch 5/100
# 9/9 [==============================] - 0s 7ms/step - loss: 21.6665 - val_loss: 20.7677
# Epoch 6/100
# 9/9 [==============================] - 0s 8ms/step - loss: 19.9045 - val_loss: 17.6196
# Epoch 7/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.1871 - val_loss: 9.8797
# Epoch 8/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.0904 - val_loss: 8.8859
# Epoch 9/100
# 9/9 [==============================] - 0s 8ms/step - loss: 8.2780 - val_loss: 7.4322
# Epoch 10/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7.6460 - val_loss: 6.9755
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7.0667 - val_loss: 6.5927
# Epoch 12/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.4838 - val_loss: 6.1172
# Epoch 13/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.9902 - val_loss: 5.7209
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.5017 - val_loss: 5.3136
# Epoch 15/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.0879 - val_loss: 4.9860
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6793 - val_loss: 4.8841
# Epoch 17/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.4505 - val_loss: 4.8079
# Epoch 18/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.2601 - val_loss: 4.8846
# Epoch 19/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.2784 - val_loss: 5.1240
# Epoch 20/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.2732 - val_loss: 4.7117
# Epoch 21/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.1222 - val_loss: 4.6805
# Epoch 22/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.0742 - val_loss: 4.6093
# Epoch 23/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.0248 - val_loss: 4.5633
# Epoch 24/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.9864 - val_loss: 4.5736
# Epoch 25/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.9322 - val_loss: 4.5971
# Epoch 26/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.8729 - val_loss: 4.4508
# Epoch 27/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.8625 - val_loss: 4.6031
# Epoch 28/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.8678 - val_loss: 4.3504
# Epoch 29/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.7243 - val_loss: 4.4276
# Epoch 30/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.6127 - val_loss: 4.3266
# Epoch 31/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.6582 - val_loss: 4.2869
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.5285 - val_loss: 4.2277
# Epoch 33/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.4838 - val_loss: 4.1727
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.4350 - val_loss: 4.1171
# Epoch 35/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.3777 - val_loss: 4.1344
# Epoch 36/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.3277 - val_loss: 4.0354
# Epoch 37/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.3337 - val_loss: 4.0456
# Epoch 38/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.3157 - val_loss: 4.0477
# Epoch 39/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3.1930 - val_loss: 3.9768
# Epoch 40/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.2113 - val_loss: 4.0966
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.1852 - val_loss: 3.9737
# Epoch 42/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.1103 - val_loss: 3.9255
# Epoch 43/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.1648 - val_loss: 3.9122
# Epoch 44/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.9961 - val_loss: 3.7901
# Epoch 45/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.9916 - val_loss: 3.8374
# Epoch 46/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.9677 - val_loss: 3.7884
# Epoch 47/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.9253 - val_loss: 3.7187
# Epoch 48/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.8500 - val_loss: 3.7432
# Epoch 49/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.8319 - val_loss: 3.6060
# Epoch 50/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.8969 - val_loss: 3.5801
# Epoch 51/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7255 - val_loss: 3.8410
# Epoch 52/100
# 9/9 [==============================] - 0s 9ms/step - loss: 2.8965 - val_loss: 3.6428
# Epoch 53/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7707 - val_loss: 3.5332
# Epoch 54/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7279 - val_loss: 3.4991
# Epoch 55/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7035 - val_loss: 3.4967
# Epoch 56/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.6311 - val_loss: 3.4582
# Epoch 57/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.6577 - val_loss: 3.4347
# Epoch 58/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7335 - val_loss: 3.4189
# Epoch 59/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.6141 - val_loss: 3.5525
# Epoch 60/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.5718 - val_loss: 3.3983
# Epoch 61/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.6066 - val_loss: 3.5189
# Epoch 62/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.5665 - val_loss: 3.4274
# Epoch 63/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.5315 - val_loss: 3.3437
# Epoch 64/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.4796 - val_loss: 3.3271
# Epoch 65/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.6186 - val_loss: 3.7040
# Epoch 66/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.6744 - val_loss: 3.3494
# Epoch 67/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.7268 - val_loss: 3.3341
# Epoch 68/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.5909 - val_loss: 3.2586
# Epoch 69/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.5160 - val_loss: 3.5945
# Epoch 70/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4319 - val_loss: 3.3154
# Epoch 71/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.5778 - val_loss: 3.2780
# Epoch 72/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.4279 - val_loss: 3.2753
# Epoch 73/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4339 - val_loss: 3.2593
# Epoch 74/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.3868 - val_loss: 3.3151
# Epoch 75/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3751 - val_loss: 3.2877
# Epoch 76/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3631 - val_loss: 3.2419
# Epoch 77/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3827 - val_loss: 3.2085
# Epoch 78/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3877 - val_loss: 3.2292
# Epoch 79/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3811 - val_loss: 3.2905
# Epoch 80/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4882 - val_loss: 3.2736
# Epoch 81/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4381 - val_loss: 3.4437
# Epoch 82/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2.3931 - val_loss: 3.2101
# Epoch 83/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3513 - val_loss: 3.1689
# Epoch 84/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3106 - val_loss: 3.1855
# Epoch 85/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3597 - val_loss: 3.5770
# Epoch 86/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4686 - val_loss: 3.1393
# Epoch 87/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3168 - val_loss: 3.1627
# Epoch 88/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3862 - val_loss: 3.2610
# Epoch 89/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2842 - val_loss: 3.1408
# Epoch 90/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2563 - val_loss: 3.1191
# Epoch 91/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2743 - val_loss: 3.2657
# Epoch 92/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3153 - val_loss: 3.1072
# Epoch 93/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2696 - val_loss: 3.0429
# Epoch 94/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3058 - val_loss: 3.2177
# Epoch 95/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2401 - val_loss: 3.0467
# Epoch 96/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2173 - val_loss: 3.0343
# Epoch 97/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2222 - val_loss: 3.4528
# Epoch 98/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.3517 - val_loss: 3.0344
# Epoch 99/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2224 - val_loss: 3.0162
# Epoch 100/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.2153 - val_loss: 3.0782
