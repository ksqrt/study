# %%
# 실습
# R2 를 음수가 아닌 0.5 이하로 줄이기
# 2. 데이터는 건들지 말것 
# 3. 레이어는 인풋 아웃풋 포함 7개 이상 
# 4. batch_size = 1
# 5. 히든레이어의 노드는 각각 10 개 이상 100 개 이하
# 6. train 70% 
# 7. epoch 100 번 이상
# 8. loss 지표는 mse or mae

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
# 1 데이터 정리
x = np.array(range(1,21))
y = np.array([i for i in range(1,21)])

# 2.as_integer_ratio
x_train, x_test,y_train,y_test = train_test_split(x,y,
    train_size=0.7,
    shuffle = True,
    random_state= 123
)

print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
# [20 13  1 16 17 10 12 11  4  2  7 19  3 14]
# [20 13  1 16 17 10 12 11  4  2  7 19  3 14]
# [15  6  5 18  9  8]
# [15  6  5 18  9  8]

# %%
# 2. 모델 구성
from random import randrange
number1 = randrange(10,100,1)
number2 = randrange(10,100,1)
number3 = randrange(10,100,1)
number4= randrange(10,100,1)
number5= randrange(10,100,1)
number6= randrange(10,100,1)
number7= randrange(10,100,1)

model = Sequential([
    Dense(number1,input_dim = 1),
    Dense(10),
    Dense(10),
    Dense(10),
    Dense(10),
    Dense(1),
  
]
         )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 33)                66
#
#  dense_1 (Dense)             (None, 10)                340
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 747
# Trainable params: 747
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. 컴파일과훈련
# 메트릭스 안에는 loss 함수를 넣어서 참고할 수 있습니다. 훈련에는 영향을 미치지 않습니다.
model.compile(loss="mae" , optimizer="adam")
model.fit(x_train,y_train,epochs=100,batch_size=1)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 958us/step - loss: 0.7359
# Epoch 2/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.4082
# Epoch 3/100
# 14/14 [==============================] - 0s 845us/step - loss: 0.7179
# Epoch 4/100
# 14/14 [==============================] - 0s 933us/step - loss: 0.4104
# Epoch 5/100
# 14/14 [==============================] - 0s 905us/step - loss: 0.5219
# Epoch 6/100
# 14/14 [==============================] - 0s 911us/step - loss: 0.1765
# Epoch 7/100
# 14/14 [==============================] - 0s 905us/step - loss: 0.1004
# Epoch 8/100
# 14/14 [==============================] - 0s 883us/step - loss: 0.2423
# Epoch 9/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.1539
# Epoch 10/100
# 14/14 [==============================] - 0s 856us/step - loss: 0.1542
# Epoch 11/100
# 14/14 [==============================] - 0s 951us/step - loss: 0.0840
# Epoch 12/100
# 14/14 [==============================] - 0s 816us/step - loss: 0.2156
# Epoch 13/100
# 14/14 [==============================] - 0s 889us/step - loss: 0.1288
# Epoch 14/100
# 14/14 [==============================] - 0s 867us/step - loss: 0.1337
# Epoch 15/100
# 14/14 [==============================] - 0s 884us/step - loss: 0.1463
# Epoch 16/100
# 14/14 [==============================] - 0s 928us/step - loss: 0.1922
# Epoch 17/100
# 14/14 [==============================] - 0s 875us/step - loss: 0.1033
# Epoch 18/100
# 14/14 [==============================] - 0s 856us/step - loss: 0.0550
# Epoch 19/100
# 14/14 [==============================] - 0s 883us/step - loss: 0.2479
# Epoch 20/100
# 14/14 [==============================] - 0s 854us/step - loss: 0.2985
# Epoch 21/100
# 14/14 [==============================] - 0s 920us/step - loss: 0.0980
# Epoch 22/100
100
# 14/14 [==============================] - 0s 844us/step - loss: 0.3028
# Epoch 65/100
# 14/14 [==============================] - 0s 913us/step - loss: 0.1552
# Epoch 66/100
# 14/14 [==============================] - 0s 917us/step - loss: 0.1309
# Epoch 67/100
# 14/14 [==============================] - 0s 858us/step - loss: 0.2177
# Epoch 68/100
# 14/14 [==============================] - 0s 847us/step - loss: 0.1185
# Epoch 69/100
# 14/14 [==============================] - 0s 925us/step - loss: 0.1678
# Epoch 70/100
# 14/14 [==============================] - 0s 848us/step - loss: 0.1059
# Epoch 71/100
# 14/14 [==============================] - 0s 838us/step - loss: 0.1723
# Epoch 72/100
# 14/14 [==============================] - 0s 840us/step - loss: 0.1356
# Epoch 73/100
# 14/14 [==============================] - 0s 956us/step - loss: 0.0729
# Epoch 74/100
# 14/14 [==============================] - 0s 872us/step - loss: 0.0737
# Epoch 75/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0823
# Epoch 76/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0662
# Epoch 77/100
# 14/14 [==============================] - 0s 926us/step - loss: 0.0742
# Epoch 78/100
# 14/14 [==============================] - 0s 960us/step - loss: 0.0338
# Epoch 79/100
# 14/14 [==============================] - 0s 883us/step - loss: 0.1248
# Epoch 80/100
# 14/14 [==============================] - 0s 846us/step - loss: 0.0433
# Epoch 81/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.0610
# Epoch 82/100
# 14/14 [==============================] - 0s 946us/step - loss: 0.1549
# Epoch 83/100
# 14/14 [==============================] - 0s 922us/step - loss: 0.1472
# Epoch 84/100
# 14/14 [==============================] - 0s 840us/step - loss: 0.0621
# Epoch 85/100
# 14/14 [==============================] - 0s 788us/step - loss: 0.0848
# Epoch 86/100
# 14/14 [==============================] - 0s 769us/step - loss: 0.0622
# Epoch 87/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.2483
# Epoch 88/100
# 14/14 [==============================] - 0s 826us/step - loss: 0.2512
# Epoch 89/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.0743
# Epoch 90/100
# 14/14 [==============================] - 0s 871us/step - loss: 0.1059
# Epoch 91/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.0317
# Epoch 92/100
# 14/14 [==============================] - 0s 922us/step - loss: 0.0870
# Epoch 93/100
# 14/14 [==============================] - 0s 884us/step - loss: 0.1141
# Epoch 94/100
# 14/14 [==============================] - 0s 859us/step - loss: 0.1320
# Epoch 95/100
# 14/14 [==============================] - 0s 857us/step - loss: 0.2020
# Epoch 96/100
# 14/14 [==============================] - 0s 844us/step - loss: 0.1421
# Epoch 97/100
# 14/14 [==============================] - 0s 826us/step - loss: 0.2038
# Epoch 98/100
# 14/14 [==============================] - 0s 958us/step - loss: 0.0933
# Epoch 99/100
# 14/14 [==============================] - 0s 912us/step - loss: 0.1969
# Epoch 100/100
# 14/14 [==============================] - 0s 921us/step - loss: 0.1362

# %%
loss = model.evaluate(x_test,y_test)
print("loss : ",loss)

from sklearn.metrics import r2_score

y_predict =model.predict(x_test)
print("=================")
print(y_test)
print(y_predict)
print("=================")


r2 = r2_score(y_test,y_predict)

print("R2 : ",r2)
# Out:
# 1/1 [==============================] - 0s 124ms/step - loss: 0.1274
# loss :  0.1274164468050003
# 1/1 [==============================] - 0s 81ms/step
# =================
# [15  6  5 18  9  8]
# [[15.197074]
#  [ 6.067368]
#  [ 5.052954]
#  [18.240309]
#  [ 9.110602]
#  [ 8.096191]]
# =================
# R2 :  0.9990698538292615

# %%
model.predict([1])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[0.99530685]], dtype=float32)
