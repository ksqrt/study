# %%
from sklearn.datasets import load_boston
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import sklearn as sk


dataset = load_boston()
x = dataset.data
y = dataset.target

# 스케일링 하기
scaler = MinMaxScaler()
# 가중치 생성후
scaler.fit(x)
# 변환
scaler.transform(x)

# %%
# 13개의 칼럼 을 가지고있는 데이터를 조회합니다
print(x.shape) #(506,13)
# print(x)
print(y.shape) #(506,)
# print(y)
# Out:
# (506, 13)
# (506,)

# %%
# 사이킥 런의 칼럼 조회기능
print(dataset.feature_names)
print(len(dataset.feature_names))
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# 13

# %%
# 사이킥런의 데이터 요약
# print(dataset.DESCR)

# %%
# 3. 모델구성
# 실습 train 0.7 이상
# 평가지표 R2 : 0.8 이상으로 뽑아내보기 / RMSE 사용

x_train, x_test,y_train,y_test = train_test_split(x,y,
    train_size=0.7,
    shuffle = True,
    random_state= 123
)

print(len(x_train))
print(len(x_test))
# Out:
# 354
# 152

# %%
from random import randrange
number1 = randrange(1,10,1)

model = Sequential([
    Dense(10,input_dim = 13,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_8 (Dense)             (None, 10)                110
#
#  dense_9 (Dense)             (None, 10)                110
#
#  dense_10 (Dense)            (None, 10)                110
#
#  dense_11 (Dense)            (None, 10)                110
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 10)                110
#
#  dense_15 (Dense)            (None, 10)                110
#
#  dense_16 (Dense)            (None, 10)                110
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,911
# Trainable params: 1,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.compile(loss="mae",optimizer="adam")

model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.25)
# loss = model.evaluate(x_test,y_test)
# print("loss : ",loss)
# y_predict =model.predict(x_test)
# print("=================")
# print(y_test)
# print(y_predict)
# print("=================")
# r2 = r2_score(y_test,y_predict)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 27ms/step - loss: 22.8915 - val_loss: 22.6824
# Epoch 2/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.7907 - val_loss: 22.6514
# Epoch 3/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.7659 - val_loss: 22.6360
# Epoch 4/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.7529 - val_loss: 22.6220
# Epoch 5/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.7345 - val_loss: 22.5985
# Epoch 6/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.7095 - val_loss: 22.5715
# Epoch 7/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.6810 - val_loss: 22.5406
# Epoch 8/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.6478 - val_loss: 22.5028
# Epoch 9/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.6040 - val_loss: 22.4464
# Epoch 10/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.5269 - val_loss: 22.3187
# Epoch 11/100
# 9/9 [==============================] - 0s 15ms/step - loss: 22.2991 - val_loss: 21.8083
# Epoch 12/100
# 9/9 [==============================] - 0s 8ms/step - loss: 21.2184 - val_loss: 19.2502
# Epoch 13/100
# 9/9 [==============================] - 0s 8ms/step - loss: 16.4039 - val_loss: 9.9532
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 10.1171 - val_loss: 9.8177
# Epoch 15/100
# 9/9 [==============================] - 0s 9ms/step - loss: 9.4671 - val_loss: 8.8894
# Epoch 16/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.3734 - val_loss: 8.4921
# Epoch 17/100
# 9/9 [==============================] - 0s 7ms/step - loss: 9.0501 - val_loss: 8.1285
# Epoch 18/100
# 9/9 [==============================] - 0s 9ms/step - loss: 8.3814 - val_loss: 7.6958
# Epoch 19/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7.7987 - val_loss: 7.3534
# Epoch 20/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7.3255 - val_loss: 6.8695
# Epoch 21/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.8727 - val_loss: 6.5455
# Epoch 22/100
# 9/9 [==============================] - 0s 8ms/step - loss: 6.5357 - val_loss: 6.2161
# Epoch 23/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.2531 - val_loss: 5.9197
# Epoch 24/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.9880 - val_loss: 5.7126
# Epoch 25/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.8703 - val_loss: 5.6048
# Epoch 26/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.6645 - val_loss: 5.6125
# Epoch 27/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.5817 - val_loss: 5.5850
# Epoch 28/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.5176 - val_loss: 5.5221
# Epoch 29/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.4285 - val_loss: 5.5461
# Epoch 30/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.4028 - val_loss: 5.5088
# Epoch 31/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.3477 - val_loss: 5.4897
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.2919 - val_loss: 5.5451
# Epoch 33/100
# 9/9 [==============================] - 0s 9ms/step - loss: 5.2408 - val_loss: 5.4843
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.2072 - val_loss: 5.4929
# Epoch 35/100
# 9/9 [==============================] - 0s 9ms/step - loss: 5.1972 - val_loss: 5.5629
# Epoch 36/100
# 9/9 [==============================] - 0s 10ms/step - loss: 5.1140 - val_loss: 5.5691
# Epoch 37/100
# 9/9 [==============================] - 0s 9ms/step - loss: 5.1657 - val_loss: 5.7034
# Epoch 38/100
# 9/9 [==============================] - 0s 9ms/step - loss: 5.1186 - val_loss: 5.5835
# Epoch 39/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5.0533 - val_loss: 5.6092
# Epoch 40/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.0530 - val_loss: 5.5788
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.9890 - val_loss: 5.5250
# Epoch 42/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.0053 - val_loss: 5.5577
# Epoch 43/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.9572 - val_loss: 5.5287
# Epoch 44/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.9655 - val_loss: 5.7678
# Epoch 45/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.1798 - val_loss: 5.6098
# Epoch 46/100
# 9/9 [==============================] - 0s 8ms/step - loss: 5.0078 - val_loss: 5.5684
# Epoch 47/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.9737 - val_loss: 5.5310
# Epoch 48/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.9317 - val_loss: 5.5646
# Epoch 49/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.9143 - val_loss: 5.5176
# Epoch 50/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.9401 - val_loss: 5.5591
# Epoch 51/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.9496 - val_loss: 5.7043
# Epoch 52/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.9040 - val_loss: 5.4734
# Epoch 53/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.8451 - val_loss: 5.4612
# Epoch 54/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.8276 - val_loss: 5.3923
# Epoch 55/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.8776 - val_loss: 5.3474
# Epoch 56/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7946 - val_loss: 5.5335
# Epoch 57/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8755 - val_loss: 5.6748
# Epoch 58/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.9118 - val_loss: 5.6097
# Epoch 59/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.8260 - val_loss: 5.3765
# Epoch 60/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.7633 - val_loss: 5.3997
# Epoch 61/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7721 - val_loss: 5.3312
# Epoch 62/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4.7459 - val_loss: 5.3823
# Epoch 63/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7434 - val_loss: 5.3774
# Epoch 64/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7498 - val_loss: 5.4927
# Epoch 65/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.8053 - val_loss: 5.6965
# Epoch 66/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.9895 - val_loss: 5.5221
# Epoch 67/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6746 - val_loss: 5.3835
# Epoch 68/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6466 - val_loss: 5.4972
# Epoch 69/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7797 - val_loss: 5.3195
# Epoch 70/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6949 - val_loss: 5.3716
# Epoch 71/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6714 - val_loss: 5.3948
# Epoch 72/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.8051 - val_loss: 5.2562
# Epoch 73/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6748 - val_loss: 5.2956
# Epoch 74/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6633 - val_loss: 5.3329
# Epoch 75/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.7756 - val_loss: 5.3960
# Epoch 76/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6866 - val_loss: 5.4044
# Epoch 77/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.6336 - val_loss: 5.2957
# Epoch 78/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6261 - val_loss: 5.3865
# Epoch 79/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.8102 - val_loss: 5.5506
# Epoch 80/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6352 - val_loss: 5.5313
# Epoch 81/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5733 - val_loss: 5.4019
# Epoch 82/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5780 - val_loss: 5.2662
# Epoch 83/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5179 - val_loss: 5.1789
# Epoch 84/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5080 - val_loss: 5.2497
# Epoch 85/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.6048 - val_loss: 5.1393
# Epoch 86/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5042 - val_loss: 5.2168
# Epoch 87/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.4841 - val_loss: 5.1922
# Epoch 88/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.4629 - val_loss: 5.1415
# Epoch 89/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.4763 - val_loss: 5.2089
# Epoch 90/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5355 - val_loss: 5.3947
# Epoch 91/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.5261 - val_loss: 5.3040
# Epoch 92/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.4376 - val_loss: 5.1320
# Epoch 93/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.3999 - val_loss: 5.2701
# Epoch 94/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.5949 - val_loss: 5.1795
# Epoch 95/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.3823 - val_loss: 5.1692
# Epoch 96/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.3821 - val_loss: 5.0950
# Epoch 97/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.3582 - val_loss: 5.1430
# Epoch 98/100
# 9/9 [==============================] - 0s 10ms/step - loss: 4.3939 - val_loss: 5.0894
# Epoch 99/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.3999 - val_loss: 5.3528
# Epoch 100/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4.3660 - val_loss: 5.1695
