# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = np.array(range(1,17))
y = np.array(range(1,17))

# %%
# from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1)

# %%
print(x_train, x_train.shape)
print(x_test, x_test.shape)
# Out:
# [ 3  7 11  5  2 15  1 16 10  9 13 12  6] (13,)
# [ 4 14  8] (3,)

# %%
# 2. 모델구성

model = Sequential([
    
    Dense(10,input_dim = 1 ,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    # 마지막 레이어는 통상 relu 넣지 않습니다. 히든레이어에 많이쓰임
    Dense(1),
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 10)                20
#
#  dense_11 (Dense)            (None, 10)                110
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 10)                110
#
#  dense_15 (Dense)            (None, 10)                110
#
#  dense_16 (Dense)            (None, 10)                110
#
#  dense_17 (Dense)            (None, 10)                110
#
#  dense_18 (Dense)            (None, 10)                110
#
#  dense_19 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 911
# Trainable params: 911
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer = 'adam')
# fit 에서 validation 을 자동으로 분리해줌
model.fit(x_train, y_train, epochs=100, batch_size=1, validation_split=0.25)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 17ms/step - loss: 83.7154 - val_loss: 100.5799
# Epoch 2/100
# 9/9 [==============================] - 0s 6ms/step - loss: 80.7850 - val_loss: 96.8338
# Epoch 3/100
# 9/9 [==============================] - 0s 6ms/step - loss: 77.1980 - val_loss: 91.7975
# Epoch 4/100
# 9/9 [==============================] - 0s 6ms/step - loss: 72.3051 - val_loss: 85.2586
# Epoch 5/100
# 9/9 [==============================] - 0s 6ms/step - loss: 65.8811 - val_loss: 77.0195
# Epoch 6/100
# 9/9 [==============================] - 0s 6ms/step - loss: 60.4561 - val_loss: 64.9076
# Epoch 7/100
# 9/9 [==============================] - 0s 6ms/step - loss: 49.3421 - val_loss: 50.4964
# Epoch 8/100
# 9/9 [==============================] - 0s 6ms/step - loss: 36.0298 - val_loss: 35.6913
# Epoch 9/100
# 9/9 [==============================] - 0s 6ms/step - loss: 22.4828 - val_loss: 19.2841
# Epoch 10/100
# 9/9 [==============================] - 0s 6ms/step - loss: 9.5292 - val_loss: 5.9408
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3.3505 - val_loss: 0.1144
# Epoch 12/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8255 - val_loss: 1.1102
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2029 - val_loss: 0.6294
# Epoch 14/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5565 - val_loss: 0.0968
# Epoch 15/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5792 - val_loss: 0.2083
# Epoch 16/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4990 - val_loss: 0.1125
# Epoch 17/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4136 - val_loss: 0.1041
# Epoch 18/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3976 - val_loss: 0.1061
# Epoch 19/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3833 - val_loss: 0.0852
# Epoch 20/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3581 - val_loss: 0.0793
# Epoch 21/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3534 - val_loss: 0.0777
# Epoch 22/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3500 - val_loss: 0.0755
# Epoch 23/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3223 - val_loss: 0.0727
# Epoch 24/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3140 - val_loss: 0.0662
# Epoch 25/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2957 - val_loss: 0.0646
# Epoch 26/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2811 - val_loss: 0.0617
# Epoch 27/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2742 - val_loss: 0.0636
# Epoch 28/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2574 - val_loss: 0.0573
# Epoch 29/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2435 - val_loss: 0.0525
# Epoch 30/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2329 - val_loss: 0.0507
# Epoch 31/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2285 - val_loss: 0.0491
# Epoch 32/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2108 - val_loss: 0.0454
# Epoch 33/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2005 - val_loss: 0.0468
# Epoch 34/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1910 - val_loss: 0.0472
# Epoch 35/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1820 - val_loss: 0.0395
# Epoch 36/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1942 - val_loss: 0.0418
# Epoch 37/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1631 - val_loss: 0.0410
# Epoch 38/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1594 - val_loss: 0.0437
# Epoch 39/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1421 - val_loss: 0.0306
# Epoch 40/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1527 - val_loss: 0.0332
# Epoch 41/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1310 - val_loss: 0.0346
# Epoch 42/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1258 - val_loss: 0.0354
# Epoch 43/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1288 - val_loss: 0.0260
# Epoch 44/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1050 - val_loss: 0.0236
# Epoch 45/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0989 - val_loss: 0.0222
# Epoch 46/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1004 - val_loss: 0.0247
# Epoch 47/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0874 - val_loss: 0.0186
# Epoch 48/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0822 - val_loss: 0.0176
# Epoch 49/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0780 - val_loss: 0.0186
# Epoch 50/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0150
# Epoch 51/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0696 - val_loss: 0.0170
# Epoch 52/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0611 - val_loss: 0.0128
# Epoch 53/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0563 - val_loss: 0.0119
# Epoch 54/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0524 - val_loss: 0.0113
# Epoch 55/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0483 - val_loss: 0.0107
# Epoch 56/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0449 - val_loss: 0.0109
# Epoch 57/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0428 - val_loss: 0.0087
# Epoch 58/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0392 - val_loss: 0.0086
# Epoch 59/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0356 - val_loss: 0.0074
# Epoch 60/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0332 - val_loss: 0.0072
# Epoch 61/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0064
# Epoch 62/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0276 - val_loss: 0.0058
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0255 - val_loss: 0.0053
# Epoch 64/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0239 - val_loss: 0.0057
# Epoch 65/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0216 - val_loss: 0.0047
# Epoch 66/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0190 - val_loss: 0.0042
# Epoch 67/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0213 - val_loss: 0.0042
# Epoch 68/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0061
# Epoch 69/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0165 - val_loss: 0.0041
# Epoch 70/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0144 - val_loss: 0.0035
# Epoch 71/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0033
# Epoch 72/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0023
# Epoch 73/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0021
# Epoch 74/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0041
# Epoch 75/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0017
# Epoch 76/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0016
# Epoch 77/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0018
# Epoch 78/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 79/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0012
# Epoch 80/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 81/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 82/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 8.9133e-04
# Epoch 83/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 8.9955e-04
# Epoch 84/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 6.7742e-04
# Epoch 85/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 5.9305e-04
# Epoch 86/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 5.4703e-04
# Epoch 87/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 4.8174e-04
# Epoch 88/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 5.7869e-04
# Epoch 89/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 4.2324e-04
# Epoch 90/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 4.0041e-04
# Epoch 91/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 3.2809e-04
# Epoch 92/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 3.0036e-04
# Epoch 93/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 2.3255e-04
# Epoch 94/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 2.1293e-04
# Epoch 95/100
# 9/9 [==============================] - 0s 5ms/step - loss: 9.9420e-04 - val_loss: 2.5305e-04
# Epoch 96/100
# 9/9 [==============================] - 0s 5ms/step - loss: 8.0366e-04 - val_loss: 1.7494e-04
# Epoch 97/100
# 9/9 [==============================] - 0s 6ms/step - loss: 7.6943e-04 - val_loss: 1.5790e-04
# Epoch 98/100
# 9/9 [==============================] - 0s 5ms/step - loss: 6.7667e-04 - val_loss: 2.0035e-04
# Epoch 99/100
# 9/9 [==============================] - 0s 6ms/step - loss: 5.6318e-04 - val_loss: 1.1148e-04
# Epoch 100/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.1698e-04 - val_loss: 1.2229e-04
