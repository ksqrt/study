# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = np.array(range(1,17))
y = np.array(range(1,17))

# %%
# from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1)
# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=1)

# %%
print(x_train, x_train.shape)
print(x_test, x_test.shape)
# print(x_val, x_val.shape)

# print(x_train)
# print(x_test)
# print(x_val)
# Out:
# [13  7  1  3 16  6  9 10 12 15] (10,)
# [ 4 14  8] (3,)
# [11  5  2] (3,)

# %%
# 2. 모델구성

model = Sequential([
    
    Dense(10,input_dim = 1 ,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    Dense(10,activation="relu"),
    # 마지막 레이어는 통상 relu 넣지 않습니다. 히든레이어에 많이쓰임
    Dense(1),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                20
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 10)                110
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_8 (Dense)             (None, 10)                110
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 911
# Trainable params: 911
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer = 'adam')
# fit 에서 validation 을 자동으로 분리해줌
model.fit(x_train, y_train, epochs=100, batch_size=1, validation_split=0.25)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0121 - val_loss: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 3/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0393
# Epoch 4/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0176 - val_loss: 0.0038
# Epoch 5/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 6/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 7/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 1.2614e-05
# Epoch 8/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.3949e-04 - val_loss: 5.5485e-04
# Epoch 9/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.7267e-04 - val_loss: 0.0061
# Epoch 10/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 11/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 12/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 13/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1814e-04 - val_loss: 1.0139e-05
# Epoch 14/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.7821e-04 - val_loss: 5.9936e-05
# Epoch 15/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.8271e-04 - val_loss: 4.5963e-04
# Epoch 16/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.7009e-04 - val_loss: 7.4585e-06
# Epoch 17/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6765e-04 - val_loss: 2.5005e-05
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.9694e-04 - val_loss: 5.7575e-04
# Epoch 19/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.0498e-04 - val_loss: 0.0047
# Epoch 20/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 21/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.5862e-04 - val_loss: 0.0033
# Epoch 22/100
# 7/7 [==============================] - 0s 7ms/step - loss: 4.6149e-04 - val_loss: 0.0029
# Epoch 23/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0114
# Epoch 24/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 25/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0185 - val_loss: 0.0120
# Epoch 26/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0299 - val_loss: 0.0038
# Epoch 27/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0488 - val_loss: 0.2236
# Epoch 28/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1692 - val_loss: 0.8217
# Epoch 29/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4463 - val_loss: 0.3844
# Epoch 30/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2757 - val_loss: 0.0139
# Epoch 31/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1217 - val_loss: 0.0909
# Epoch 32/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0573 - val_loss: 0.0959
# Epoch 33/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0498 - val_loss: 0.0521
# Epoch 34/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0195 - val_loss: 0.0077
# Epoch 35/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 36/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0160
# Epoch 37/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 38/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 9.3040e-04
# Epoch 39/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0104
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 41/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0062
# Epoch 42/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 43/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 44/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.7004e-04 - val_loss: 0.0023
# Epoch 45/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 3.6974e-04
# Epoch 46/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.7124e-04 - val_loss: 3.6044e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 6ms/step - loss: 4.3915e-04 - val_loss: 2.1537e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.2531e-04 - val_loss: 3.5597e-04
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8544e-04 - val_loss: 1.1107e-04
# Epoch 50/100
# 7/7 [==============================] - 0s 6ms/step - loss: 4.9115e-04 - val_loss: 2.8630e-05
# Epoch 51/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.8713e-04 - val_loss: 7.3241e-05
# Epoch 52/100
# 7/7 [==============================] - 0s 6ms/step - loss: 2.0940e-04 - val_loss: 1.5224e-05
# Epoch 53/100
# 7/7 [==============================] - 0s 6ms/step - loss: 3.2626e-04 - val_loss: 2.1615e-05
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.9753e-04 - val_loss: 1.4745e-05
# Epoch 55/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.4692e-04 - val_loss: 1.5180e-05
# Epoch 56/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5494e-04 - val_loss: 3.5642e-05
# Epoch 57/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9103e-04 - val_loss: 5.7387e-05
# Epoch 58/100
# 7/7 [==============================] - 0s 6ms/step - loss: 3.1175e-04 - val_loss: 1.3204e-05
# Epoch 59/100
# 7/7 [==============================] - 0s 6ms/step - loss: 2.4840e-04 - val_loss: 1.9024e-05
# Epoch 60/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2736e-04 - val_loss: 1.0887e-05
# Epoch 61/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.8863e-05 - val_loss: 4.7256e-05
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5706e-04 - val_loss: 3.8511e-05
# Epoch 63/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.8948e-05 - val_loss: 1.6743e-05
# Epoch 64/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5045e-04 - val_loss: 2.1317e-05
# Epoch 65/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1341e-04 - val_loss: 1.0644e-05
# Epoch 66/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8377e-05 - val_loss: 2.8707e-05
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 8.2175e-05 - val_loss: 1.0641e-05
# Epoch 68/100
# 7/7 [==============================] - 0s 7ms/step - loss: 8.3596e-05 - val_loss: 1.3023e-05
# Epoch 69/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.8254e-04 - val_loss: 7.7902e-05
# Epoch 70/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.2549e-04 - val_loss: 4.2443e-04
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 2.5148e-04 - val_loss: 3.0133e-05
# Epoch 72/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1745e-04 - val_loss: 2.3883e-05
# Epoch 73/100
# 7/7 [==============================] - 0s 7ms/step - loss: 6.5216e-05 - val_loss: 5.7169e-05
# Epoch 74/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0650e-04 - val_loss: 1.1179e-04
# Epoch 75/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.8398e-05 - val_loss: 1.2906e-04
# Epoch 76/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6461e-04 - val_loss: 3.4432e-04
# Epoch 77/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9384e-04 - val_loss: 6.6428e-05
# Epoch 78/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.3292e-04 - val_loss: 2.5482e-05
# Epoch 79/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.1726e-05 - val_loss: 1.8641e-05
# Epoch 80/100
# 7/7 [==============================] - 0s 7ms/step - loss: 6.4287e-05 - val_loss: 8.7485e-06
# Epoch 81/100
# 7/7 [==============================] - 0s 7ms/step - loss: 6.6747e-05 - val_loss: 9.2769e-06
# Epoch 82/100
# 7/7 [==============================] - 0s 6ms/step - loss: 6.9178e-05 - val_loss: 1.1188e-05
# Epoch 83/100
# 7/7 [==============================] - 0s 7ms/step - loss: 8.5486e-05 - val_loss: 1.0405e-05
# Epoch 84/100
# 7/7 [==============================] - 0s 6ms/step - loss: 8.2341e-05 - val_loss: 6.9435e-06
# Epoch 85/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0310e-04 - val_loss: 3.8306e-05
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1238e-04 - val_loss: 2.1126e-04
# Epoch 87/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.7691e-04 - val_loss: 9.2639e-04
# Epoch 88/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.2369e-04 - val_loss: 6.7299e-04
# Epoch 89/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5065e-04 - val_loss: 1.6216e-04
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0269e-04 - val_loss: 2.8736e-05
# Epoch 91/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.2043e-05 - val_loss: 6.9129e-05
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.5867e-05 - val_loss: 1.3605e-05
# Epoch 93/100
# 7/7 [==============================] - 0s 7ms/step - loss: 5.4439e-05 - val_loss: 3.8953e-05
# Epoch 94/100
# 7/7 [==============================] - 0s 7ms/step - loss: 5.0057e-05 - val_loss: 2.2750e-05
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 6.3009e-05 - val_loss: 8.7760e-06
# Epoch 96/100
# 7/7 [==============================] - 0s 7ms/step - loss: 5.8826e-05 - val_loss: 5.0674e-05
# Epoch 97/100
# 7/7 [==============================] - 0s 7ms/step - loss: 6.8308e-05 - val_loss: 8.6941e-05
# Epoch 98/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3262e-04 - val_loss: 7.0537e-04
# Epoch 99/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.7716e-04 - val_loss: 3.0645e-04
# Epoch 100/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.3775e-04 - val_loss: 9.4598e-04
