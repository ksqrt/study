# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN,LSTM,GRU

dataset = np.array([1,2,3,4,5,6,7])

# %%
# x = np.array([[i,i+1,i+2] for i in dataset])
# y = np.array([i+3 for i in dataset])

x = np.array([
 [1 ,2 ,3],
 [2 ,3 ,4],
 [3 ,4 ,5],
 [4 ,5 ,6],
 [5 ,6 ,7],
 [6 ,7 ,8],
 [7 ,8 ,9],
 [8,9,10],
 [20,30,40],
 [30,40,50],
 [40,50,60]])

y = np.array([4,5,6,7,8,9,10,11,50,60,70])



print(x)
print(y)
# Out:
# [[ 1  2  3]
#  [ 2  3  4]
#  [ 3  4  5]
#  [ 4  5  6]
#  [ 5  6  7]
#  [ 6  7  8]
#  [ 7  8  9]
#  [ 8  9 10]
#  [20 30 40]
#  [30 40 50]
#  [40 50 60]]
# [ 4  5  6  7  8  9 10 11 50 60 70]

# %%
print(x.shape,y.shape)
# Out:
# (11, 3) (11,)

# %%
# 모델을 리쉐이프해서 7개 데이터 를 (3,1) 로 만들자
x = x.reshape(len(x),3,1)
x
# Out:
# array([[[ 1],
#         [ 2],
#         [ 3]],
#
#        [[ 2],
#         [ 3],
#         [ 4]],
#
#        [[ 3],
#         [ 4],
#         [ 5]],
#
#        [[ 4],
#         [ 5],
#         [ 6]],
#
#        [[ 5],
#         [ 6],
#         [ 7]],
#
#        [[ 6],
#         [ 7],
#         [ 8]],
#
#        [[ 7],
#         [ 8],
#         [ 9]],
#
#        [[ 8],
#         [ 9],
#         [10]],
#
#        [[20],
#         [30],
#         [40]],
#
#        [[30],
#         [40],
#         [50]],
#
#        [[40],
#         [50],
#         [60]]])

# %%
print(x.shape,y.shape)
# Out:
# (11, 3, 1) (11,)

# %%
# RNN 모델구성
model = Sequential([
    # input_shape 는 행 무시 
    GRU(128,input_shape=(3,1)),
    Dense(16,activation="relu"),
    Dense(1)
])
# 파라미터의 값 :
# RNN x 4 (출력 , 입력 ,삭제게이트)
# ( unit 개수 ) * (unit 개수 + feature 개수)*4
# 기본 rnn ㅇㅇ이처럼 파라미터의 값이 매우 많아서 연산량이 매우 많다
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 128)               50304
#
#  dense_2 (Dense)             (None, 16)                2064
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 52,385
# Trainable params: 52,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 훈련
model.compile(loss="mae",optimizer="adam")
model.fit(x,y,epochs=100,batch_size=1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 4ms/step - loss: 21.8173
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 20.9794
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 20.1958
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 18.8837
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 16.5714
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 15.4374
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 14.9945
# Epoch 8/100
# 11/11 [==============================] - 0s 3ms/step - loss: 14.4161
# Epoch 9/100
# 11/11 [==============================] - 0s 6ms/step - loss: 14.0338
# Epoch 10/100
# 11/11 [==============================] - 0s 4ms/step - loss: 13.7004
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 13.6702
# Epoch 12/100
# 11/11 [==============================] - 0s 4ms/step - loss: 13.1680
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 13.0391
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 12.7632
# Epoch 15/100
# 11/11 [==============================] - 0s 5ms/step - loss: 12.4980
# Epoch 16/100
# 11/11 [==============================] - 0s 3ms/step - loss: 12.2691
# Epoch 17/100
# 11/11 [==============================] - 0s 4ms/step - loss: 12.1956
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 11.9736
# Epoch 19/100
# 11/11 [==============================] - 0s 3ms/step - loss: 12.0144
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 11.5219
# Epoch 21/100
# 11/11 [==============================] - 0s 3ms/step - loss: 11.1657
# Epoch 22/100
# 11/11 [==============================] - 0s 5ms/step - loss: 10.9247
# Epoch 23/100
# 11/11 [==============================] - 0s 3ms/step - loss: 10.8197
# Epoch 24/100
# 11/11 [==============================] - 0s 3ms/step - loss: 10.6651
# Epoch 25/100
# 11/11 [==============================] - 0s 3ms/step - loss: 10.1731
# Epoch 26/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8819
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 9.6478
# Epoch 28/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5007
# Epoch 29/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0092
# Epoch 30/100
# 11/11 [==============================] - 0s 4ms/step - loss: 8.7652
# Epoch 31/100
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5745
# Epoch 32/100
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2827
# Epoch 33/100
# 11/11 [==============================] - 0s 3ms/step - loss: 8.1713
# Epoch 34/100
# 11/11 [==============================] - 0s 4ms/step - loss: 7.4521
# Epoch 35/100
# 11/11 [==============================] - 0s 3ms/step - loss: 7.2606
# Epoch 36/100
# 11/11 [==============================] - 0s 4ms/step - loss: 6.8627
# Epoch 37/100
# 11/11 [==============================] - 0s 4ms/step - loss: 6.5411
# Epoch 38/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.1394
# Epoch 39/100
# 11/11 [==============================] - 0s 4ms/step - loss: 5.6680
# Epoch 40/100
# 11/11 [==============================] - 0s 3ms/step - loss: 5.2073
# Epoch 41/100
# 11/11 [==============================] - 0s 3ms/step - loss: 4.7621
# Epoch 42/100
# 11/11 [==============================] - 0s 3ms/step - loss: 4.4306
# Epoch 43/100
# 11/11 [==============================] - 0s 4ms/step - loss: 4.2185
# Epoch 44/100
# 11/11 [==============================] - 0s 4ms/step - loss: 3.4199
# Epoch 45/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.4850
# Epoch 46/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2386
# Epoch 47/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.3326
# Epoch 48/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.9114
# Epoch 49/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.0053
# Epoch 50/100
# 11/11 [==============================] - 0s 4ms/step - loss: 2.7888
# Epoch 51/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4125
# Epoch 52/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2064
# Epoch 53/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.8435
# Epoch 54/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8972
# Epoch 55/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8971
# Epoch 56/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.6521
# Epoch 57/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7083
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0122
# Epoch 59/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.5208
# Epoch 60/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.8605
# Epoch 61/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0385
# Epoch 62/100
# 11/11 [==============================] - 0s 4ms/step - loss: 2.4781
# Epoch 63/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9037
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4259
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1525
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1332
# Epoch 67/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6413
# Epoch 68/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2117
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7600
# Epoch 70/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2070
# Epoch 71/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.0539
# Epoch 72/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.3114
# Epoch 73/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8045
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0211
# Epoch 75/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.7803
# Epoch 76/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.6125
# Epoch 77/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.3038
# Epoch 78/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8743
# Epoch 79/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4831
# Epoch 80/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2556
# Epoch 81/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9967
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2024
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0443
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1667
# Epoch 85/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8124
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6723
# Epoch 87/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9846
# Epoch 88/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8502
# Epoch 89/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7450
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9936
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7627
# Epoch 92/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7237
# Epoch 93/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5926
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.9771
# Epoch 95/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9416
# Epoch 96/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5679
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5812
# Epoch 98/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5010
# Epoch 99/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4198
# Epoch 100/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6890

# %%
loss = model.evaluate(x,y)

print(loss)
# Out:
# 1/1 [==============================] - 0s 279ms/step - loss: 1.4312
# 1.4312052726745605

# %%
test = np.array([[[50],[60],[70]]])
result = model.predict(test)
print("결과",result)
# Out:
# 결과 [[73.73273]]
