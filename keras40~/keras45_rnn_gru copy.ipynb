# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN,LSTM,GRU

dataset = np.array([1,2,3,4,5,6,7])

# %%
# x = np.array([[i,i+1,i+2] for i in dataset])
# y = np.array([i+3 for i in dataset])

x = np.array([
 [1 ,2 ,3],
 [2 ,3 ,4],
 [3 ,4 ,5],
 [4 ,5 ,6],
 [5 ,6 ,7],
 [6 ,7 ,8],
 [7 ,8 ,9],
 [8,9,10],
 [20,30,40],
 [30,40,50],
 [40,50,60]])

y = np.array([4,5,6,7,8,9,10,11,50,60,70])



print(x)
print(y)
# Out:
# [[ 1  2  3]
#  [ 2  3  4]
#  [ 3  4  5]
#  [ 4  5  6]
#  [ 5  6  7]
#  [ 6  7  8]
#  [ 7  8  9]
#  [ 8  9 10]
#  [20 30 40]
#  [30 40 50]
#  [40 50 60]]
# [ 4  5  6  7  8  9 10 11 50 60 70]

# %%
print(x.shape,y.shape)
# Out:
# (11, 3) (11,)

# %%
# 모델을 리쉐이프해서 7개 데이터 를 (3,1) 로 만들자
x = x.reshape(len(x),3,1)
x
# Out:
# array([[[ 1],
#         [ 2],
#         [ 3]],
#
#        [[ 2],
#         [ 3],
#         [ 4]],
#
#        [[ 3],
#         [ 4],
#         [ 5]],
#
#        [[ 4],
#         [ 5],
#         [ 6]],
#
#        [[ 5],
#         [ 6],
#         [ 7]],
#
#        [[ 6],
#         [ 7],
#         [ 8]],
#
#        [[ 7],
#         [ 8],
#         [ 9]],
#
#        [[ 8],
#         [ 9],
#         [10]],
#
#        [[20],
#         [30],
#         [40]],
#
#        [[30],
#         [40],
#         [50]],
#
#        [[40],
#         [50],
#         [60]]])

# %%
print(x.shape,y.shape)
# Out:
# (11, 3, 1) (11,)

# %%
# RNN 모델구성
model = Sequential([
    # input_shape 는 행 무시 
    GRU(128,input_shape=(3,1)),
    Dense(16,activation="relu"),
    Dense(1)
])
# 파라미터의 값 :
# RNN x 4 (출력 , 입력 ,삭제게이트)
# ( unit 개수 ) * (unit 개수 + feature 개수)*4
# 기본 rnn ㅇㅇ이처럼 파라미터의 값이 매우 많아서 연산량이 매우 많다
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 128)               66560
#
#  dense_20 (Dense)            (None, 16)                2064
#
#  dense_21 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 68,641
# Trainable params: 68,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 훈련
model.compile(loss="mae",optimizer="adam")
model.fit(x,y,epochs=100,batch_size=1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 4ms/step - loss: 21.4240
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 20.6503
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 19.4958
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 17.6407
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 15.3566
# Epoch 6/100
# 11/11 [==============================] - 0s 4ms/step - loss: 14.6522
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 14.3720
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 14.0150
# Epoch 9/100
# 11/11 [==============================] - 0s 3ms/step - loss: 13.7477
# Epoch 10/100
# 11/11 [==============================] - 0s 3ms/step - loss: 13.5141
# Epoch 11/100
# 11/11 [==============================] - 0s 3ms/step - loss: 13.3213
# Epoch 12/100
# 11/11 [==============================] - 0s 3ms/step - loss: 13.1790
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 12.9058
# Epoch 14/100
# 11/11 [==============================] - 0s 3ms/step - loss: 12.6204
# Epoch 15/100
# 11/11 [==============================] - 0s 3ms/step - loss: 12.2558
# Epoch 16/100
# 11/11 [==============================] - 0s 3ms/step - loss: 12.0043
# Epoch 17/100
# 11/11 [==============================] - 0s 3ms/step - loss: 11.4961
# Epoch 18/100
# 11/11 [==============================] - 0s 3ms/step - loss: 11.2044
# Epoch 19/100
# 11/11 [==============================] - 0s 3ms/step - loss: 10.4084
# Epoch 20/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.9694
# Epoch 21/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5404
# Epoch 22/100
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0038
# Epoch 23/100
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7640
# Epoch 24/100
# 11/11 [==============================] - 0s 3ms/step - loss: 7.9886
# Epoch 25/100
# 11/11 [==============================] - 0s 3ms/step - loss: 7.5205
# Epoch 26/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.8932
# Epoch 27/100
# 11/11 [==============================] - 0s 3ms/step - loss: 6.2002
# Epoch 28/100
# 11/11 [==============================] - 0s 3ms/step - loss: 5.5096
# Epoch 29/100
# 11/11 [==============================] - 0s 3ms/step - loss: 4.8310
# Epoch 30/100
# 11/11 [==============================] - 0s 3ms/step - loss: 4.1258
# Epoch 31/100
# 11/11 [==============================] - 0s 3ms/step - loss: 3.4636
# Epoch 32/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.7240
# Epoch 33/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.5704
# Epoch 34/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.6845
# Epoch 35/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3082
# Epoch 36/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0114
# Epoch 37/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7615
# Epoch 38/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.6350
# Epoch 39/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.1465
# Epoch 40/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0469
# Epoch 41/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9189
# Epoch 42/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4280
# Epoch 43/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0042
# Epoch 44/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9927
# Epoch 45/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0628
# Epoch 46/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0056
# Epoch 47/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4253
# Epoch 48/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9382
# Epoch 49/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0079
# Epoch 50/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6369
# Epoch 51/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4713
# Epoch 52/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0488
# Epoch 53/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2165
# Epoch 54/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7679
# Epoch 55/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6991
# Epoch 56/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4512
# Epoch 57/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6084
# Epoch 58/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7825
# Epoch 59/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4328
# Epoch 60/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5387
# Epoch 61/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7738
# Epoch 62/100
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3191
# Epoch 63/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5632
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2548
# Epoch 65/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0244
# Epoch 66/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6848
# Epoch 67/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6548
# Epoch 68/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4652
# Epoch 69/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5101
# Epoch 70/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7376
# Epoch 71/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3113
# Epoch 72/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5389
# Epoch 73/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4208
# Epoch 74/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9195
# Epoch 75/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9875
# Epoch 76/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7080
# Epoch 77/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4483
# Epoch 78/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0114
# Epoch 79/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3930
# Epoch 80/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6001
# Epoch 81/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4103
# Epoch 82/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9768
# Epoch 83/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5249
# Epoch 84/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5842
# Epoch 85/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7560
# Epoch 86/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4705
# Epoch 87/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4681
# Epoch 88/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6770
# Epoch 89/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5695
# Epoch 90/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4486
# Epoch 91/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4911
# Epoch 92/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5352
# Epoch 93/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3636
# Epoch 94/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6361
# Epoch 95/100
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1594
# Epoch 96/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7613
# Epoch 97/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3210
# Epoch 98/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5472
# Epoch 99/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6294
# Epoch 100/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3162

# %%
loss = model.evaluate(x,y)

print(loss)
# Out:
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4893
# 0.48932763934135437

# %%
test = np.array([[[50],[60],[70]]])
result = model.predict(test)
print("결과",result)
# Out:
# 결과 [[73.41857]]
